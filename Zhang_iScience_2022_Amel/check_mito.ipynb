# %%
# %%bash
#
# gppy txinfo -g "./ref/Apis_mellifera.Amel_HAv3.1.62.filtered.gtf" > ./metadata/Amel_txinfo.tsv

# %% [markdown]
# - First, use gppy to convert the GTF file to TSV, and determine which `gene_id` correspond to the `chrom` of the mitochondria.
# - In adata.var, create a new column "mt", and mark the genes belonging to mitochondria in adata.var.gene_ids as True.

# %%
from pyfaidx import Fasta

# %%
Amel_fa = Fasta('./ref/Apis_mellifera.Amel_HAv3.1.dna.toplevel.fa')

# %%
for name in Amel_fa.keys():
    if name.startswith("CM"):
        print(f"{name}: {len(Amel_fa[name])}")
# Out:
# CM009931.2: 27754200
# CM009932.2: 16089512
# CM009933.2: 13619445
# CM009934.2: 13404451
# CM009935.2: 13896941
# CM009936.2: 17789102
# CM009937.2: 14198698
# CM009938.2: 12717210
# CM009939.2: 12354651
# CM009940.2: 12360052
# CM009941.2: 16352600
# CM009942.2: 11514234
# CM009943.2: 11279722
# CM009944.2: 10670842
# CM009945.2: 9534514
# CM009946.2: 7238532
# CM009947.2: 16343

# %% [markdown]
# CM009947.2 is mito

# %%
import pandas as pd

Amel_txinfo = pd.read_csv("./metadata/Amel_txinfo.tsv", sep = "\t")
Amel_txinfo
# Out:
#             tx_name       gene_id           chrom strand  nexon  tx_len  \
# 0      XM_006559882  LOC100576147      CM009931.2      +      1    4102
# 1      XM_006561922  LOC100577342      CM009931.2      +      4    1173
# 2      XM_026445023     LOC551556      CM009931.2      -      4    1369
# 3      XM_006563296     LOC727596      CM009931.2      +      4    1065
# 4      XM_026446341     LOC727596      CM009931.2      +      5    1018
# ...             ...           ...             ...    ...    ...     ...
# 27549  XR_003306463  LOC113219386  QIUM02000194.1      +      4     572
# 27550  XR_003306467  LOC113219386  QIUM02000194.1      +      4     485
# 27551  XR_003306465  LOC113219386  QIUM02000194.1      +      4     483
# 27552  XR_003306464  LOC113219386  QIUM02000194.1      +      4     604
# 27553  XM_026445952  LOC113219358  QIUM02000217.1      -      2     888
#
#        cds_len  utr5_len  utr3_len    gene_biotype gene_name gene_source  \
# ...

# %%
mito_txinfo = Amel_txinfo[Amel_txinfo["chrom"] == "CM009947.2"]
mito_txinfo
# Out:
#                    tx_name        gene_id       chrom strand  nexon  tx_len  \
# 27348  GeneID_807695_df_mr  GeneID_807695  CM009947.2      +      1    1566
# 27349  GeneID_807696_df_mr  GeneID_807696  CM009947.2      +      1     681
# 27350  GeneID_807699_df_mr  GeneID_807699  CM009947.2      +      1     159
# 27351  GeneID_807700_df_mr  GeneID_807700  CM009947.2      +      1     678
# 27352  GeneID_807690_df_mr  GeneID_807690  CM009947.2      +      1     780
# 27353  GeneID_807702_df_mr  GeneID_807702  CM009947.2      -      1    1344
# 27354  GeneID_807693_df_mr  GeneID_807693  CM009947.2      +      1    1152
# 27355  GeneID_807692_df_mr  GeneID_807692  CM009947.2      -      1     918
# 27356  GeneID_807698_df_mr  GeneID_807698  CM009947.2      -      1    1665
# 27357  GeneID_807701_df_mr  GeneID_807701  CM009947.2      +      1    1002
# 27358  GeneID_807691_df_mr  GeneID_807691  CM009947.2      +      1     354
# ...

# %%
mito_txinfo_geneid = set(mito_txinfo["gene_id"].to_list())
mito_txinfo_geneid
# Out:
# {'GeneID_807690',
#  'GeneID_807691',
#  'GeneID_807692',
#  'GeneID_807693',
#  'GeneID_807694',
#  'GeneID_807695',
#  'GeneID_807696',
#  'GeneID_807697',
#  'GeneID_807698',
#  'GeneID_807699',
#  'GeneID_807700',
#  'GeneID_807701',
#  'GeneID_807702'}

# %%
import scanpy as sc

F1_adata = sc.read_10x_h5("./h5_from_fastq2matrix/F1.h5")
# Out:
# /home/liuzhiyu/Software/miniconda3/envs/downstream_analysis/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/liuzhiyu/Software/miniconda3/envs/downstream_analysis/lib/python3.10/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
F1_adata.var
# Out:
#                   gene_ids    feature_types           genome
# LOC100576147  LOC100576147  Gene Expression  A_mel_mkref_out
# LOC100577342  LOC100577342  Gene Expression  A_mel_mkref_out
# LOC551556        LOC551556  Gene Expression  A_mel_mkref_out
# LOC727596        LOC727596  Gene Expression  A_mel_mkref_out
# LOC102653881  LOC102653881  Gene Expression  A_mel_mkref_out
# ...                    ...              ...              ...
# LOC113219384  LOC113219384  Gene Expression  A_mel_mkref_out
# LOC107965808  LOC107965808  Gene Expression  A_mel_mkref_out
# LOC113219385  LOC113219385  Gene Expression  A_mel_mkref_out
# LOC113219386  LOC113219386  Gene Expression  A_mel_mkref_out
# LOC113219358  LOC113219358  Gene Expression  A_mel_mkref_out
#
# [11793 rows x 3 columns]

# %%
F1_var_names_set = set(F1_adata.var_names)
F1_gene_ids_set = set(F1_adata.var["gene_ids"].to_list())

print(len(F1_var_names_set & mito_txinfo_geneid))
print(len(F1_gene_ids_set & mito_txinfo_geneid))
# Out:
# 0
# 13

# %% [markdown]
# ↑ The naming in `var_names` and `gene_ids` is not entirely consistent.

# %%
F1_adata.var[F1_adata.var["gene_ids"] == "GeneID_807693"]
# Out:
#            gene_ids    feature_types           genome
# CYTB  GeneID_807693  Gene Expression  A_mel_mkref_out

# %%
F1_geneids = set(F1_adata.var["gene_ids"].to_list())
F1_geneids
# Out:
# {'LOC100578187',
#  'LOC113218902',
#  'LOC412471',
#  'LOC411021',
#  'LOC100576818',
#  'LOC726394',
#  'LOC413370',
#  'LOC408874',
#  'LOC102655950',
#  'LOC100578875',
#  'LOC412296',
#  'LOC113219040',
#  'LOC413481',
#  'LOC409820',
#  'LOC113219037',
#  'LOC412439',
#  'LOC725593',
#  'LOC724321',
#  'LOC409359',
#  'LOC408884',
#  'LOC726167',
#  'LOC412504',
#  'LOC725527',
#  'LOC726449',
#  'LOC412305',
#  'LOC724913',
#  'LOC410094',
#  'LOC551464',
#  'LOC100576799',
#  'GeneID_726146dufb2',
#  'LOC409588',
#  'LOC552524',
#  'LOC552446',
#  'LOC726375',
#  'LOC411036',
#  'LOC100577106',
#  'LOC552758',
#  'GeneID_100576480',
#  'LOC725511',
#  'LOC100577575',
#  'LOC113219254',
#  'LOC100577646',
#  'LOC725252',
#  'LOC724227',
#  'LOC551619',
#  'LOC411336',
#  'LOC726024',
#  'LOC727568',
#  'LOC551116',
#  'LOC100577132',
#  'LOC113218887',
#  'LOC113218718',
#  'LOC410514',
#  'LOC113218985',
#  'GeneID_406155',
#  'LOC100577145',
#  'LOC552064',
# ...

# %%
print(len(mito_txinfo_geneid & F1_geneids))
print(mito_txinfo_geneid & F1_geneids)
# Out:
# 13
# {'GeneID_807695', 'GeneID_807701', 'GeneID_807694', 'GeneID_807693', 'GeneID_807698', 'GeneID_807691', 'GeneID_807697', 'GeneID_807699', 'GeneID_807690', 'GeneID_807696', 'GeneID_807702', 'GeneID_807700', 'GeneID_807692'}

# %% [markdown]
# ↑ The F1 Anndata contains 13 mitochondrial genes. Same as `/data/share/data/Zhou_lab_seq_data/20251022_scRNA_lzy/1_LZU/check_mt.py`
#
# In the expression matrix provided by `Zhang et al., 2022`, nearly 450 genes were labeled as `mt` in a single Anndata object, <mark style="background: #FF5582A6;">which is an error in their workflow.</mark>:
#
# ![image](../.image/iscience_mito.png)

# %% [markdown]
# Save mito gene_id as txt
#
# This file will be used in QC process:

# %%
mito_txinfo["gene_id"].to_csv("./metadata/mito.txt", header=False, index=False)
